# %% [markdown]
# # Installation of necessary packages
#
# Under Python 3.10 environment, you could execute `pip install -r requirements.txt` in the terminal to install all the necessary packages.

# %%
# %pwd
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: ipykernel in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: torch in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: torchvision in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.19.0)
# Requirement already satisfied: einops in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.8.0)
# Requirement already satisfied: scikit-image in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.24.0)
# Requirement already satisfied: opencv-python in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (4.10.0.84)
# Requirement already satisfied: matplotlib in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.9.2)
# Requirement already satisfied: tqdm in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.66.5)
# Requirement already satisfied: kornia in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.7.3)
# Requirement already satisfied: accelerate in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.33.0)
# Requirement already satisfied: transformers in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (4.44.1)
# Requirement already satisfied: evaluate in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.4.2)
# Requirement already satisfied: deepspeed in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (0.14.5)
# Requirement already satisfied: comm>=0.1.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: psutil in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: filelock in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: sympy in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (1.13.2)
# Requirement already satisfied: networkx in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (3.3)
# Requirement already satisfied: jinja2 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torch->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->-r requirements.txt (line 2)) (12.6.20)
# Requirement already satisfied: numpy in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torchvision->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from torchvision->-r requirements.txt (line 3)) (10.4.0)
# Requirement already satisfied: scipy>=1.9 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: imageio>=2.33 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 5)) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 5)) (2024.8.10)
# Requirement already satisfied: lazy-loader>=0.4 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 7)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 7)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.9.0)
# Requirement already satisfied: kornia-rs>=0.1.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from kornia->-r requirements.txt (line 9)) (0.1.5)
# Requirement already satisfied: pyyaml in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 10)) (0.24.6)
# Requirement already satisfied: safetensors>=0.3.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 10)) (0.4.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 11)) (2024.7.24)
# Requirement already satisfied: requests in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 11)) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 11)) (0.19.1)
# Requirement already satisfied: datasets>=2.0.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from evaluate->-r requirements.txt (line 12)) (2.21.0)
# Requirement already satisfied: dill in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from evaluate->-r requirements.txt (line 12)) (0.3.8)
# Requirement already satisfied: pandas in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from evaluate->-r requirements.txt (line 12)) (2.2.2)
# Requirement already satisfied: xxhash in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from evaluate->-r requirements.txt (line 12)) (3.5.0)
# Requirement already satisfied: multiprocess in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from evaluate->-r requirements.txt (line 12)) (0.70.16)
# Requirement already satisfied: hjson in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from deepspeed->-r requirements.txt (line 13)) (3.1.0)
# Requirement already satisfied: ninja in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from deepspeed->-r requirements.txt (line 13)) (1.11.1.1)
# Requirement already satisfied: nvidia-ml-py in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from deepspeed->-r requirements.txt (line 13)) (12.560.30)
# Requirement already satisfied: py-cpuinfo in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from deepspeed->-r requirements.txt (line 13)) (9.0.0)
# Requirement already satisfied: pydantic in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from deepspeed->-r requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (17.0.0)
# Requirement already satisfied: aiohttp in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (3.10.5)
# Requirement already satisfied: decorator in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: exceptiongroup in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: six>=1.5 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 11)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 11)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 11)) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from jinja2->torch->-r requirements.txt (line 2)) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from pandas->evaluate->-r requirements.txt (line 12)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from pandas->evaluate->-r requirements.txt (line 12)) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from pydantic->deepspeed->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from pydantic->deepspeed->-r requirements.txt (line 13)) (2.20.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from sympy->torch->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate->-r requirements.txt (line 12)) (4.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Launch training process
#
# ## Set configurations
# Execute first `accelerate config` to set configurations for the train. If you can install [**DeepSpeed**](https://github.com/microsoft/DeepSpeed), than you could use DeepSpeed module in [**Accelerate**](https://huggingface.co/docs/accelerate/index) to speed up the training process.
#
# #### It is recommended (by me) to choose the following, for a configuration without using **DeepSpeed**:
#
# In which compute environment are you running? -> **This machine**,
#
# Which type of machine are you using? -> **No distributed training**,
#
# Do you want to run your training on CPU only? -> **NO**,
#
# Do you wish to optimize your script with torch dynamo? -> **NO**,
#
# Do you want to use DeepSpeed? -> **NO**,
#
# What GPU(s) should be used for training on this machine as a comma-seperated list? -> **all**,
#
# Would you like to enable numa efficiency?(Currently only supported on NVIDIA hardware) -> **yes**,
#
# Do you wish to use FP16 or BF16 (mixed precision)? -> **fp16**.

# %% [markdown]
# #### If you have **DeepSpeed**:
#
# ZeRO optimization stage 0 is enough for training on 1 GPU. Gradient accumulation depends on the training batch size, usually we keep $batch\_size \times gradient\_accumulation = 8$. In addition, the use of fp8 (mixed precision) requires further installation.
#
# It is recommended (by me) to choose the following:
#
# How many gradient accumulation steps you're passing in your script? -> 1,
#
# Do you want to use gradient clipping? -> yes,
#
# What is the gradient clipping value? -> 1.0,
#
# Do you want to enable `deepspeed.zero.Init` when using ZeRO Stage-3 for constructing massive models? -> NO,
#
# Do you want to enable Mixture-of-Experts training (MoE)? -> NO,
#
# How many GPU(s) should be used for distributed training? -> 1.

# %% [markdown]
# ## Launch training
#
# Execute `accelerate launch trainC.py` can directly trigger the training process. You could change the parameters in the file, for instance, number of epochs, learning rates.

# %%
# !accelerate launch trainC.py
# Out:
# [2024-08-28 11:24:58,399] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
# /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/kornia/feature/lightglue.py:44: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)
# [2024-08-28 11:25:02,316] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
# /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# [2024-08-28 11:25:02,791] [INFO] [comm.py:637:init_distributed] cdb=None
# [2024-08-28 11:25:02,791] [INFO] [comm.py:668:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/home/caffin/桌面/image_satellite/trainC.py", line 39, in <module>
# [rank0]:     model, optimizer, train_dataloader, scheduler = accelerator.prepare(
# [rank0]:   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/accelerate/accelerator.py", line 1303, in prepare
# [rank0]:     result = self._prepare_deepspeed(*args)
# [rank0]:   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/accelerate/accelerator.py", line 1700, in _prepare_deepspeed
# [rank0]:     deepspeed_plugin.set_moe_leaf_modules(model)
# [rank0]:   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/accelerate/utils/dataclasses.py", line 1186, in set_moe_leaf_modules
# [rank0]:     raise Exception(
# [rank0]: Exception: Could not find a transformer layer class called '' to wrap in the model.
# E0828 11:25:04.084000 135525924497216 torch/distributed/elastic/multiprocessing/api.py:833] failed (exitcode: 1) local_rank: 0 (pid: 272275) of binary: /home/caffin/anaconda3/envs/test/bin/python
# Traceback (most recent call last):
#   File "/home/caffin/anaconda3/envs/test/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/accelerate/commands/accelerate_cli.py", line 48, in main
#     args.func(args)
#   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/accelerate/commands/launch.py", line 1091, in launch_command
#     deepspeed_launcher(args)
#   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/accelerate/commands/launch.py", line 787, in deepspeed_launcher
#     distrib_run.run(args)
#   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/torch/distributed/run.py", line 892, in run
#     elastic_launch(
#   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/torch/distributed/launcher/api.py", line 133, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#   File "/home/caffin/anaconda3/envs/test/lib/python3.10/site-packages/torch/distributed/launcher/api.py", line 264, in launch_agent
#     raise ChildFailedError(
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# trainC.py FAILED
# ------------------------------------------------------------
# Failures:
#   <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2024-08-28_11:25:04
#   host      : caffin-NUC11BTMi7
#   rank      : 0 (local_rank: 0)
#   exitcode  : 1 (pid: 272275)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================

# %% [markdown]
# If you encounter errors like `RuntimeError: expected scalar type Half but found Float`, or `RuntimeError: Input type (float) and bias type (c10::Half) should be the same`. Please adapt the corresponding types, by adding `.to(torch.float16)` or `.to(input.dtype)`.

# %% [markdown]
# # Inference pipeline
#
# Inference could be done directly in **example.ipynb**.
